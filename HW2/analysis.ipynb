# %% [markdown]
# <a href="https://colab.research.google.com/github/luiscalvi/CSC349/blob/main/HW2/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets?

# %% [markdown]
# I didn't encounter any challenges on the assignment. Compared to pre packaged datasets, Kaggle datasets require more initial inspection but here it was fine. Google Colab made it easy to load the database.

# %% [markdown]
# 2. How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?

# %% [markdown]
# I looked at the dataset for missing values and look at the data type of the columns. The ones with missing num values used imputation. The other issues were fixed separately.

# %% [markdown]
# 3. Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing steps.

# %% [markdown]
# Scikit-Learn's ColumnTransformer and Pipeline made data preparation by organizing multiple preprocessing steps into a pipeline workflow. The column transformer allows different types of transformations to be performed to numerical and categorical data like imputation, scaling, and encoding. The pipeline makes sure that the transformations happen correctly and consistently.

# %% [markdown]
# 4. Based on your correlation matrix and heatmap, which features show the strongest relationships with the target variable (attack_detected), and what operational insights do these relationships reveal?

# %% [markdown]
# The ones with the highest correlation values were the features with the strongest correlation. They are useful for identifying network attacks, showing which network activity is the most related to attacks. Features with stronger correlations would help security to prioritize specific indicators
