# %% [markdown]
# <a href="https://colab.research.google.com/github/luiscalvi/CSC349/blob/main/HW1/Analysis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?

# %% [markdown]
# The steps for managing files is creating a Github repo to connect or clone into Colab. You can then organize the directory with each file for whatever assignments. After one is done with the file on Colab, it can be saved and committed to Github through, file, save a copy in Github. There you choose the repo and branch that you want to push it to and add a commit text to keep the organization intact and know what you did.

# %% [markdown]
# # 2. Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?

# %% [markdown]
# All the files ran perfectly and there wasn't anything I needed to do. A few of them just needed the correct libraries and packages to run the rest of the code.

# %% [markdown]
# # 3. Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).

# %% [markdown]
# First I created the repo on Github, then made the HW1 directory. After all that I downloaded all 5 files on Modules 0 and ran them accordingly. I tested them one by one, uploading them to my repo after I was finished with a commit message. I kept the name the same since I felt that it was already perfect with Notebook 1,2,3…

# %% [markdown]
# # 4. Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?

# %% [markdown]
# I would say that having a very strong understanding of Python syntax is important because of data manipulation. Data structures comes in handy with things like lists, sets, loops, functions, and conditionals since they are used constantly with data manipulation and algorithms. They are fundamental to what we are learning and not knowing them becomes harder to understand the concept of machine learning.
